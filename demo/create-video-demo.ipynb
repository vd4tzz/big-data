# %%
from ultralytics import YOLO

modelPath = "../yolov8n-train/weights/best.pt"
model = YOLO(modelPath)

# %%
videoPath = "sample.mp4"
model.predict(videoPath, save=True)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/450) e:\big-data\demo\sample.mp4: 384x640 1 car, 20 motorbikes, 46.5ms
# video 1/1 (frame 2/450) e:\big-data\demo\sample.mp4: 384x640 2 cars, 18 motorbikes, 32.5ms
# video 1/1 (frame 3/450) e:\big-data\demo\sample.mp4: 384x640 3 cars, 22 motorbikes, 31.5ms
# video 1/1 (frame 4/450) e:\big-data\demo\sample.mp4: 384x640 3 cars, 22 motorbikes, 39.0ms
# ...
